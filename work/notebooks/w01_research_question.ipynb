# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ahmedasker1/FlyRank_Repo/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *I am choosing the Refresh / Content Opportunity Scoring lane. Relying on manual rules (like updating pages just because they are 6 months old) is inefficient. Using ML to prioritize which pages need immediate review can save the content team's time and protect search traffic*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# *The Decision: Which declining pages should the content team review first?  The Action: Adding the page to a prioritized content refresh queue.  Cost of a wrong call:False Positive: Wasting a writer's time updating a page that is already performing well.  False Negative: Losing organic traffic because a genuinely declining page was ignored.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, sys, subprocess
import pandas as pd

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    if os.path.basename(os.getcwd()) != REPO_DIR:
        os.chdir(REPO_DIR)
else:
    while not os.path.isdir("data/raw") and os.getcwd() != "/":
        os.chdir("..")

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

declining_count = (df['trend_direction'].str.lower() == 'down').sum()
total_pages = len(df)
declining_pct = (declining_count / total_pages) * 100

at_risk_impressions = df[df['trend_direction'].str.lower() == 'down']['impressions_90d'].sum()

print(f"1. Out of {total_pages} pages, {declining_count} pages ({declining_pct:.1f}%) are declining.")
print(f"2. There are {at_risk_impressions:,} impressions in the last 90 days at risk from these declining pages.")
print("\nConclusion: Prioritizing these pages with an ML model has immediate business value.")
# Out:
# 1. Out of 30000 pages, 16262 pages (54.2%) are declining.
# 2. There are 79,994,363 impressions in the last 90 days at risk from these declining pages.
#
# Conclusion: Prioritizing these pages with an ML model has immediate business value.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *I cannot claim to predict or decode Google's algorithm, nor can I definitively prove that a refresh will cause a traffic recovery. I can only claim to build a decision-support model based on observed historical signals that ranks at-risk pages better than random guessing.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
